# %% [markdown]
# # 18 政策时序与替代指标稳健性
# 所有规格预先固定；primary 仍为 contemporaneous primary metric。

# %%
import pandas as pd

timing = pd.read_csv('results/chapter3/timing_robustness.csv')
metrics = pd.read_csv('results/chapter3/metric_robustness.csv')
display(timing)
display(metrics)
assert timing['model'].eq('lagged_primary').all()
assert set(metrics['model']) == {'expanding', 'full_report', 'theme'}
assert timing['province_clusters'].eq(7).all() and metrics['province_clusters'].eq(7).all()
print('Enterprise outcomes are simulated training data.')
